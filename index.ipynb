# %% [markdown]
# # Metall Tutorial
#
# Metall depends on [Boost C++ Libraries](https://www.boost.org/).

# %% [markdown]
# ## Recommended Flow
#
# ![tutorial_flow.png](attachment:tutorial_flow.png)

# %% [markdown]
# ## Build
#
# ```bash
#
# cd $HOME/metall/tutorial/hands_on
#
# g++-8 -std=c++17 [tutorial_example.cpp] -lstdc++fs -pthread -I../../include -I$HOME/boost
#
# # All tutorial programs do not take command-line options
# ./a.out
#
# ```
